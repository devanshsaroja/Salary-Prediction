# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
#https://colab.research.google.com/drive/1hVe3v5GhDCcXxMeatWX-fsWZ-vphUwVr?authuser=0#scrollTo=lT59n9AOhyLn

# %% [markdown]
# # Importing the Dataset

# %%
df=pd.read_csv('Balitmore_salry.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                name                       jobtitle agencyid  \
# 0           0     Aaron,Keontae E                 AIDE BLUE CHIP   W02200
# 1           1    Aaron,Patricia G  Facilities/Office Services II   A03031
# 2           2       Aaron,Petra L     ASSISTANT STATE'S ATTORNEY   A29005
# 3           3  Abaineh,Yohannes T                 EPIDEMIOLOGIST   A65026
# 4           4    Abbene,Anthony M         POLICE OFFICER TRAINEE   A99416
#
#                     agency  hire_date  hire_month  hire_year  annualsalary
# 0             Youth Summer         10           6       2013         11310
# 1       OED-Employment Dev         24          10       1979         53428
# 2  States Attorneys Office         25           9       2006         68300
# 3   HLTH-Health Department         23           7       2009         62000
# 4        Police Department         24           7       2013         43999

# %% [markdown]
# # EDA-Exploratory Data Analysis

# %%
df.shape
# Out:
# (18895, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18895 entries, 0 to 18894
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18895 non-null  int64
#  1   name          18895 non-null  object
#  2   jobtitle      18895 non-null  object
#  3   agencyid      18895 non-null  object
#  4   agency        18895 non-null  object
#  5   hire_date     18895 non-null  int64
#  6   hire_month    18895 non-null  int64
#  7   hire_year     18895 non-null  int64
#  8   annualsalary  18895 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0     hire_date    hire_month     hire_year   annualsalary
# count  18895.000000  18895.000000  18895.000000  18895.000000   18895.000000
# mean    9519.609262     15.764806      6.369675   2004.078328   39547.804763
# std     5467.766632      8.386260      2.948706     10.391949   24865.587963
# min        0.000000      1.000000      1.000000   1952.000000       0.000000
# 25%     4799.500000      9.000000      5.000000   1998.000000   11310.000000
# 50%     9525.000000     16.000000      6.000000   2007.000000   36203.000000
# 75%    14253.500000     22.000000      8.000000   2013.000000   60300.000000
# max    18980.000000     31.000000     12.000000   2014.000000  148200.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'jobtitle', 'agencyid', 'agency', 'hire_date',
#        'hire_month', 'hire_year', 'annualsalary'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# name            0
# jobtitle        0
# agencyid        0
# agency          0
# hire_date       0
# hire_month      0
# hire_year       0
# annualsalary    0
# dtype: int64

# %%
df.agencyid
# Out:
# 0        W02200
# 1        A03031
# 2        A29005
# 3        A65026
# 4        A99416
#           ...
# 18890    W02235
# 18891    W02629
# 18892    A99416
# 18893    A99262
# 18894    A50206
# Name: agencyid, Length: 18895, dtype: object

# %%
df.agencyid.value_counts()
# Out:
# agencyid
# P04001    316
# C90786    276
# W02629    193
# P04002    191
# A99416    166
#          ...
# W02400      1
# W02595      1
# W07901      1
# W02313      1
# W02339      1
# Name: count, Length: 1177, dtype: int64

# %%
agency_id_name_mapping = df.groupby('agencyid')['agency'].agg(list)
agency_id_name_mapping
# Out:
# agencyid
# A01001    [Mayors Office, Mayors Office, Mayors Office, ...
# A01020    [Mayor's Office, Mayor's Office, Mayor's Offic...
# A01030    [Mayors Office, Mayors Office, Mayors Office, ...
# A02001    [City Council, City Council, City Council, Cit...
# A02002    [City Council, City Council, City Council, Cit...
#                                 ...
# W02698                                       [Youth Summer]
# W02699                                       [Youth Summer]
# W07900    [Youth Temp Adult, Youth Temp Adult, Youth Tem...
# W07901                                   [Youth Temp Adult]
# W07905                 [Youth Temp Adult, Youth Temp Adult]
# Name: agency, Length: 1177, dtype: object

# %%
df.annualsalary.plot.box()
# Out:
# <Axes: >

# %%
#plotting top 10 jobs based on hiring
df.jobtitle.value_counts(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='jobtitle'>

# %%
#plot top 10 jobs with highest salary
df.groupby(['jobtitle'])['annualsalary'].count().sort_values(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='jobtitle'>

# %%
#plot top 10 Agency that has highest number of employees
df.groupby(['agency'])['name'].count().sort_values(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='agency'>

# %%
df.head()
# Out:
#    Unnamed: 0                name                       jobtitle agencyid  \
# 0           0     Aaron,Keontae E                 AIDE BLUE CHIP   W02200
# 1           1    Aaron,Patricia G  Facilities/Office Services II   A03031
# 2           2       Aaron,Petra L     ASSISTANT STATE'S ATTORNEY   A29005
# 3           3  Abaineh,Yohannes T                 EPIDEMIOLOGIST   A65026
# 4           4    Abbene,Anthony M         POLICE OFFICER TRAINEE   A99416
#
#                     agency  hire_date  hire_month  hire_year  annualsalary
# 0             Youth Summer         10           6       2013         11310
# 1       OED-Employment Dev         24          10       1979         53428
# 2  States Attorneys Office         25           9       2006         68300
# 3   HLTH-Health Department         23           7       2009         62000
# 4        Police Department         24           7       2013         43999

# %%
#plot Highest Salary vs year graph
df.groupby(['hire_year'])['annualsalary'].count().sort_values(ascending=False).head(10).plot(kind='bar')

# Adding y-axis label
plt.ylabel('Annual-Salary')
# Out:
# Text(0, 0.5, 'Annual-Salary')

# %%
#plot a graph to check which month most of the people are hired
df.groupby(['hire_month'])['name'].count().sort_values(ascending=False).plot(kind='bar')
plt.ylabel("No. of Employees")
# Out:
# Text(0, 0.5, 'No. of Employees')

# %%
#plot a pairplot
sns.pairplot(df)

# %%
#plot heatmap
newdf=df.drop(['name','agency','agencyid','jobtitle'],axis=1)
sns.heatmap(newdf.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Unnamed: 0                name                       jobtitle agencyid  \
# 0           0     Aaron,Keontae E                 AIDE BLUE CHIP   W02200
# 1           1    Aaron,Patricia G  Facilities/Office Services II   A03031
# 2           2       Aaron,Petra L     ASSISTANT STATE'S ATTORNEY   A29005
# 3           3  Abaineh,Yohannes T                 EPIDEMIOLOGIST   A65026
# 4           4    Abbene,Anthony M         POLICE OFFICER TRAINEE   A99416
#
#                     agency  hire_date  hire_month  hire_year  annualsalary
# 0             Youth Summer         10           6       2013         11310
# 1       OED-Employment Dev         24          10       1979         53428
# 2  States Attorneys Office         25           9       2006         68300
# 3   HLTH-Health Department         23           7       2009         62000
# 4        Police Department         24           7       2013         43999

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# Feature columns (excluding the columns to be dropped)
X = df.drop(['name', 'agency', 'agencyid', 'jobtitle', 'annualsalary'], axis=1).values

# Target variable (annual salary)
y = df['annualsalary'].values

# %%
X
# Out:
# array([[  10,    6, 2013],
#        [  24,   10, 1979],
#        [  25,    9, 2006],
#        ...,
#        [  17,   12, 2013],
#        [  23,    1, 2013],
#        [  15,   10, 1979]])

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.333, random_state=42)

# Scale the features and the target variable
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Fit the scaler to the training features and transform both training and test data
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Fit the scaler to the target and transform both training and test target data
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()  # Make y_train a 2D array for scaling
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).flatten()  # Same for y_test

# %%
#model
model=SVR(kernel='rbf')

# %%
# Train the model with scaled data
model.fit(X_train_scaled, y_train_scaled)
# Out:
# SVR()

# %%
# Make predictions on the test set
y_pred_scaled = model.predict(X_test_scaled)

# Inverse transform the predictions to get back to the original scale
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

# Evaluate the model's performance
model_score = model.score(X_test_scaled, y_test_scaled)

# %%
#Performace of the Model
model.score(X_test_scaled,y_test_scaled)
# Out:
# 0.4713390573955569

# %%
#Accuracy
from sklearn.metrics import r2_score
r2_score(y_test_scaled,y_pred_scaled)
# Out:
# 0.4713390573955569

# %%
#PREDICTING SALARY FOR different dates
i_date = int(input("Enter date in the format dd - "))
i_month = int(input("Enter month in the format mm- "))
i_year = int(input("Enter year in the format yyyy - "))
X_pred = scaler_X.transform(np.array([[i_date, i_month, i_year]]))
y_pred_scale=model.predict(X_pred)
y_predd = scaler_y.inverse_transform(y_pred_scale.reshape(-1, 1)).flatten()
print("Salary:",y_predd)
# Out:
# Enter date in the format dd - 29
# Enter month in the format mm- 7
# Enter year in the format yyyy - 2013
# Salary: [23217.5637938]

# %%
df.head(50)
# Out:
#                      name                        jobtitle agencyid  \
# 0         Aaron,Keontae E                  AIDE BLUE CHIP   W02200
# 1        Aaron,Patricia G   Facilities/Office Services II   A03031
# 2           Aaron,Petra L      ASSISTANT STATE'S ATTORNEY   A29005
# 3      Abaineh,Yohannes T                  EPIDEMIOLOGIST   A65026
# 4        Abbene,Anthony M          POLICE OFFICER TRAINEE   A99416
# 5          Abbey,Emmanuel           CONTRACT SERV SPEC II   A40001
# 6      Abdal-Rahim,Naim A     EMT Firefighter Suppression   A64120
# 7          Abdi,Ezekiel W                 POLICE SERGEANT   A99127
# 8     Abdul Adl,Attrice A        RADIO DISPATCHER SHERIFF   A38410
# 9       Abdul Aziz,Hajr E                  AIDE BLUE CHIP   W02097
# 10    Abdul Aziz,Jennah A                  AIDE BLUE CHIP   W02097
# 11     Abdul Aziz,Yaqub M                  AIDE BLUE CHIP   W02097
# 12       Abdul Hamid,Umar                    SECRETARY II   A06009
# 13  Abdul Saboor,Jamillah                    SECRETARY II   A75054
# 14    Abdul Wajid,Amani B                  AIDE BLUE CHIP   W02185
# 15  Abdul-Jabbar,Bushra A     SOCIAL SERVICES COORDINATOR   A06015
# 16       Abdullah,Aisha W            OFFICE ASSISTANT III   A85301
# 17     Abdullah,Beverly A                      TYPIST III   A06004
# 18     Abdullahi,Sharon M                    911 OPERATOR   A40301
# 19  Abdur Rahim,Raghiba S                  AIDE BLUE CHIP   W02412
# 20     Abendschein,John V                    TEST MONITOR   P83004
# 21   Abendschein,Rosemary               OFFICE SUPERVISOR   A90002
# 22              Abid,Amal        PUBLIC WORKS INSPECTOR I   A49104
# 23             Abid,Paula      RECREATION ARTS INSTRUCTOR   P04001
# 24            Able,John D                LABORER (Hourly)   B70357
# 25           Able,Jowan A                  AIDE BLUE CHIP   W02140
# 26     Abler II,Stanley C                   PARAMEDIC CRT   A64462
# 27           Abney,Amanda     CLERICAL ASSISTANT I COURTS   A31009
# 28        Abraham,Donta D                LABORER (Hourly)   B70357
# 29       Abraham,Santhosh                    ACCOUNTANT I   A50603
# 30       Abraham,Sharon M               HOUSING INSPECTOR   A06043
# 31           Abrams,Maria  OFFICE SERVICES ASSISTANT II S   A29008
# 32          Abrams,Maxine      COLLECTIONS REPRESENTATIVE   A14003
# 33          Abrams,Ronald                  STOREKEEPER II   A49320
# 34           Abrams,Terry      RECREATION ARTS INSTRUCTOR   P04001
# 35         Abron,Taylor E                  AIDE BLUE CHIP   W02314
# 36       Abshire,Rodney M            MAINTENANCE MECHANIC   A91014
# 37       Abu Hakim,Hassan                  AIDE BLUE CHIP   W02146
# 38     Abual Gasim,Nada A                  CROSSING GUARD   C90786
# 39            Abugo,Susan   COMMUNITY HEALTH NURSE II (10   A65102
# 40      Abu-Hakim,Kendall  ELECTRICAL MECH ST LIGHTING II   A49390
# 41      Abukhdeir,Momen M  STAFF ASSISTANT MAYOR'S OFFICE   A01001
# 42          Acharya,Abi N                  AIDE BLUE CHIP   W02629
# 43          Acharya,Jhuma                  AIDE BLUE CHIP   W02543
# 44         Acharya,Keshab                  AIDE BLUE CHIP   W02543
# 45         Ackiss,Deana M            POLICE OFFICER (EID)   A99001
# 46          Ackwood,Karen                  SERV ASST LBRY   A75008
# 47         Acord,Ashley M          POLICE OFFICER TRAINEE   A99416
# 48   Acosta Bueso,Pedro A                  AIDE BLUE CHIP   W02461
# 49       Acquah,Nanaama A                  AIDE BLUE CHIP   W02629
#
#                       agency  hire_date  hire_month  hire_year  annualsalary
# 0               Youth Summer         10           6       2013         11310
# 1         OED-Employment Dev         24          10       1979         53428
# 2    States Attorneys Office         25           9       2006         68300
# 3     HLTH-Health Department         23           7       2009         62000
# 4          Police Department         24           7       2013         43999
# 5        M-R Info Technology          1           5       2013         52000
# 6            Fire Department         30           3       2011         62175
# 7          Police Department         14           6       2007         70918
# 8           Sheriff's Office          2           9       1999         42438
# 9               Youth Summer         18           6       2014         11310
# 10              Youth Summer         16           6       2014         11310
# 11              Youth Summer          9           6       2014         11310
# 12   Housing & Community Dev         17           1       1995         34692
# 13  Enoch Pratt Free Library         27           7       2009         33215
# 14              Youth Summer         13           6       2013         11310
# 15   Housing & Community Dev         14           4       2008         41202
# 16          General Services         11           2       2013         28802
# 17   Housing & Community Dev          1          12       1986         37199
# 18       M-R Info Technology         10           6       2004         44190
# 19              Youth Summer         10           6       2013         11310
# 20           HR-Test Monitor         16           3       2013         20800
# 21             TRANS-Traffic         19           7       1973         47382
# 22            TRANS-Highways          2          12       2013         34522
# 23   R&P-Recreation (part-ti         25           6       2007         22880
# 24    DPW-Solid Waste (wkly)          9           5       1994         31866
# 25              Youth Summer         12           6       2012         11310
# 26           Fire Department         20           3       2006         65480
# 27             Circuit Court         13          10       2008         35560
# 28    DPW-Solid Waste (wkly)         16          10       2000         30119
# 29   DPW-Water & Waste Water         31          12       2007         47809
# 30   Housing & Community Dev         15          12       1997         49377
# 31   States Attorneys Office         19           9       2011         31275
# 32           FIN-Collections         26           8       2002         36627
# 33            TRANS-Highways         11           3       1996         37694
# 34   R&P-Recreation (part-ti         19           6       2014         20800
# 35              Youth Summer         21           5       2014         11310
# 36     M-R Convention Center         19          12       1996         44655
# 37              Youth Summer         10           6       2013         11310
# 38     TRANS-Crossing Guards         22          11       2004         10038
# 39    HLTH-Health Department         27           8       2003         56670
# 40            TRANS-Highways          9           1       2012         34725
# 41             Mayors Office         24           6       2006         50000
# 42              Youth Summer         21           5       2014         11310
# 43              Youth Summer         21           5       2014         11310
# 44              Youth Summer         21           5       2014         11310
# 45         Police Department          4           1       2000         66320
# 46  Enoch Pratt Free Library         19           2       1992         16744
# 47         Police Department         10           4       2014         43999
# 48              Youth Summer         12           6       2012         11310
# 49              Youth Summer         21           5       2014         11310
